# %% [markdown]
# <a href="https://colab.research.google.com/github/LexisHWorth/HUM1600/blob/main/Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > Week 4 Lab
# Level: Beginner
# Name: Alexis Hollingsworth
#   UID: u1275318

# %%
# Review: Data Types
# Identify Data Types
print(type(42))
print(type(3.14159))
print(type("Hello, world!"))
print(type(True))
print(type(False))
print(type("12345"))
print(type(7.0))

# Evaluate Expressions
print(10 + 5)
print(10 / 2)
print(10 > 2)
print("Hello" + " " + "World")
print(4 * 3.5)

# Boolean Logic Practice
print(True and False)
print(False or True)
print(not True)
print(5 > 3 and 2 < 4)
print(3 == 3 or 5 != 5)

# Challenge Task
print(20)
print(2.5)
print("Python" + " " + "Programming")
print(False)

# Review Variables
# Declaring & Using Variables
age = 31
pi_value = 3.14159
greeting = "Hi! How are you?"
is_python_fun = False
print(age)
print(pi_value)
print(greeting)
print(is_python_fun)

# Checking Variable Data Types
print(type(age))
print(type(pi_value))
print(type(greeting))
print(type(is_python_fun))

# Updating Variable Values
age = 30
pi_value = 3.14
greeting = "Hallo! Wie geht es Ihnen?"
is_python_fun = True
print(age)
print(pi_value)
print(greeting)
print(is_python_fun)

# Variable Operations
age += 5
pi_value *= 2
greeting = "Hello" + " " + "Python"
is_python_fun = not is_python_fun
print(age)
print(pi_value)
print(greeting)
print(not (is_python_fun))

# Boolean Expressions with Variables
print(age > 20 and age < 40)
print(pi_value == 3.14 or pi_value > 3)
print(not (age < 18))

# Challenge
name = "Alexis"
year_of_birth = 1994
current_year = 2025
approximate_age = current_year - year_of_birth
print(f"Hello, {name}. You are approximately {approximate_age} years old.")

# New: User Input
# Getting Input From Users
user_name = (input("Enter your name: "))
print(f"Hello, {user_name}!")

# Converting User Input
user_age = int(input("Enter your age: "))
print(f"Next year, you will be {user_age + 1}.")

pi = float(input("Enter the value of pi: "))
print(type(pi))

# Performing Operations on User Input
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))
sum_values = num1 + num2 + num3
print(f"The sum of the three numbers is {sum_values}")

# Challenge Task
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
birth_year = int(input("Enter your birth year: "))
current_year = 2025
age = current_year - birth_year
print(f"Hello, {first_name} {last_name}. You are approximately {age} years old.")

# New: Decisions
# Using if Statements
age = int(input("Enter your age: "))
if age >= 18:
    print("You are an adult.")

# Using if-else Statements
if age >= 18:
    print("You are an adult.")
else:
    print("You are not an adult.")

# Using if-elif-else Statements
age= int(input("Enter your age again please: "))
if age < 13:
    print("Child")
elif age < 18  > 12:
    print("Teenager")
elif age <= 61  >= 18:
    print("Adult")
elif age > 61 > 200:
    print("Elderly")
elif age > 1000:
      print("Most honorable Shizun, please teach this humble student the path to immortality")
else:
    print("That is impossible.")

# Challenge Task
number = float(input("Enter a number: "))
if number > 0:
    print("Your number is positive.")
elif number < 0:
    print("Your number is negative.")
else:
    print("You entered zero.")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>
# <class 'str'>
# <class 'float'>
# 15
# 5.0
# True
# Hello World
# 14.0
# False
# True
# False
# True
# True
# 20
# 2.5
# Python Programming
# False
# 31
# 3.14159
# Hi! How are you?
# False
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 30
# 3.14
# Hallo! Wie geht es Ihnen?
# True
# 35
# 6.28
# Hello Python
# True
# True
# True
# True
# Hello, Alexis. You are approximately 31 years old.
